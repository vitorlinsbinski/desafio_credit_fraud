# %%
import pandas as pd

# %%
df = pd.read_csv('../data/origin/df_fraud_credit.csv', sep=",")

# %%
df.head()
# Out:
#     timestamp                             sending_address  \
# 0  1618185002  0x9d32d0bf2c00f41ce7ca01b66e174cc4dcb0c1da
# 1  1698642474  0xd6e251c23cbf52dbd472f079147873e655d8096f
# 2  1619180066  0x2e0925b922fed01f6a85d213ae2718f54b8ca305
# 3  1591413882  0x93efefc25fcaf31d7695f28018d7a11ece55457f
# 4  1611257295  0xad3b8de45d63f5cce28aef9a82cf30c397c6ceb9
#
#                             receiving_address   amount transaction_type  \
# 0  0x39f82e1c09bc6d7baccc1e79e5621ff812f50572  67435.0         transfer
# 1  0x51e8fbe24f124e0e30a614e14401b9bbfed5384c      1.0         purchase
# 2  0x52c7911879f783d590af45bda0c0ef2b8536706f  66211.0         purchase
# 3  0x8ac3b7bd531b3a833032f07d4e47c7af6ea7bace  14998.0         transfer
# 4  0x6fdc047c2391615b3facd79b4588c7e9106e49f2  66002.0             sale
#
#   location_region  ip_prefix  login_frequency  session_duration  \
# 0          Europe    192.000                3                48
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 13 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   timestamp          1048575 non-null  int64
#  1   sending_address    1048575 non-null  str
#  2   receiving_address  1048575 non-null  str
#  3   amount             1048575 non-null  str
#  4   transaction_type   1048575 non-null  str
#  5   location_region    1048575 non-null  str
#  6   ip_prefix          1048575 non-null  float64
#  7   login_frequency    1048575 non-null  int64
#  8   session_duration   1048575 non-null  int64
#  9   purchase_pattern   1048575 non-null  str
#  10  age_group          1048575 non-null  str
#  11  risk_score         1048575 non-null  str
#  12  anomaly            1048575 non-null  str
# dtypes: float64(1), int64(3), str(9)
# memory usage: 104.0 MB

# %%
df["transaction_type"].value_counts()
# Out:
# transaction_type
# sale        334079
# purchase    332692
# transfer    295151
# scam         52705
# phishing     33948
# Name: count, dtype: int64

# %%
df["location_region"].value_counts()
# Out:
# location_region
# North America    210145
# Europe           209749
# Asia             208742
# South America    207821
# Africa           206323
# 0                  5795
# Name: count, dtype: int64

# %%
df["age_group"].value_counts()
# Out:
# age_group
# veteran        352576
# new            348775
# established    347224
# Name: count, dtype: int64

# %%
df[df["amount"].str.strip().str.lower() == "none"] = None

# %%
df["amount"] = df["amount"].astype(float)

# %%
df["amount"].isna().sum()
# Out:
# np.int64(5641)

# %%
df.columns
# Out:
# Index(['timestamp', 'sending_address', 'receiving_address', 'amount',
#        'transaction_type', 'location_region', 'ip_prefix', 'login_frequency',
#        'session_duration', 'purchase_pattern', 'age_group', 'risk_score',
#        'anomaly'],
#       dtype='str')

# %%
# df.dropna(subset=["sending_address", "receiving_address"], inplace=True)

# %%
df.shape
# Out:
# (1048575, 13)

# %%
df.head()
# Out:
#       timestamp                             sending_address  \
# 0  1.618185e+09  0x9d32d0bf2c00f41ce7ca01b66e174cc4dcb0c1da
# 1  1.698642e+09  0xd6e251c23cbf52dbd472f079147873e655d8096f
# 2  1.619180e+09  0x2e0925b922fed01f6a85d213ae2718f54b8ca305
# 3  1.591414e+09  0x93efefc25fcaf31d7695f28018d7a11ece55457f
# 4  1.611257e+09  0xad3b8de45d63f5cce28aef9a82cf30c397c6ceb9
#
#                             receiving_address   amount transaction_type  \
# 0  0x39f82e1c09bc6d7baccc1e79e5621ff812f50572  67435.0         transfer
# 1  0x51e8fbe24f124e0e30a614e14401b9bbfed5384c      1.0         purchase
# 2  0x52c7911879f783d590af45bda0c0ef2b8536706f  66211.0         purchase
# 3  0x8ac3b7bd531b3a833032f07d4e47c7af6ea7bace  14998.0         transfer
# 4  0x6fdc047c2391615b3facd79b4588c7e9106e49f2  66002.0             sale
#
#   location_region  ip_prefix  login_frequency  session_duration  \
# 0          Europe    192.000              3.0              48.0
# ...

# %%
df["transaction_datetime"] = pd.to_datetime(df["timestamp"], unit="s")

# %%
df.head()
# Out:
#       timestamp                             sending_address  \
# 0  1.618185e+09  0x9d32d0bf2c00f41ce7ca01b66e174cc4dcb0c1da
# 1  1.698642e+09  0xd6e251c23cbf52dbd472f079147873e655d8096f
# 2  1.619180e+09  0x2e0925b922fed01f6a85d213ae2718f54b8ca305
# 3  1.591414e+09  0x93efefc25fcaf31d7695f28018d7a11ece55457f
# 4  1.611257e+09  0xad3b8de45d63f5cce28aef9a82cf30c397c6ceb9
#
#                             receiving_address   amount transaction_type  \
# 0  0x39f82e1c09bc6d7baccc1e79e5621ff812f50572  67435.0         transfer
# 1  0x51e8fbe24f124e0e30a614e14401b9bbfed5384c      1.0         purchase
# 2  0x52c7911879f783d590af45bda0c0ef2b8536706f  66211.0         purchase
# 3  0x8ac3b7bd531b3a833032f07d4e47c7af6ea7bace  14998.0         transfer
# 4  0x6fdc047c2391615b3facd79b4588c7e9106e49f2  66002.0             sale
#
#   location_region  ip_prefix  login_frequency  session_duration  \
# 0          Europe    192.000              3.0              48.0
# ...

# %%
df.drop(columns=["timestamp"], inplace=True)

# %%
df.head()
# Out:
#                               sending_address  \
# 0  0x9d32d0bf2c00f41ce7ca01b66e174cc4dcb0c1da
# 1  0xd6e251c23cbf52dbd472f079147873e655d8096f
# 2  0x2e0925b922fed01f6a85d213ae2718f54b8ca305
# 3  0x93efefc25fcaf31d7695f28018d7a11ece55457f
# 4  0xad3b8de45d63f5cce28aef9a82cf30c397c6ceb9
#
#                             receiving_address   amount transaction_type  \
# 0  0x39f82e1c09bc6d7baccc1e79e5621ff812f50572  67435.0         transfer
# 1  0x51e8fbe24f124e0e30a614e14401b9bbfed5384c      1.0         purchase
# 2  0x52c7911879f783d590af45bda0c0ef2b8536706f  66211.0         purchase
# 3  0x8ac3b7bd531b3a833032f07d4e47c7af6ea7bace  14998.0         transfer
# 4  0x6fdc047c2391615b3facd79b4588c7e9106e49f2  66002.0             sale
#
#   location_region  ip_prefix  login_frequency  session_duration  \
# 0          Europe    192.000              3.0              48.0
# 1   South America    172.000              5.0              61.0
# ...

# %%
df[df["amount"] < 0]
# Out:
# Empty DataFrame
# Columns: [sending_address, receiving_address, amount, transaction_type, location_region, ip_prefix, login_frequency, session_duration, purchase_pattern, age_group, risk_score, anomaly, transaction_datetime]
# Index: []

# %%
df.columns
# Out:
# Index(['sending_address', 'receiving_address', 'amount', 'transaction_type',
#        'location_region', 'ip_prefix', 'login_frequency', 'session_duration',
#        'purchase_pattern', 'age_group', 'risk_score', 'anomaly',
#        'transaction_datetime'],
#       dtype='str')

# %%
df[df.duplicated(keep=False)]
# Out:
#         sending_address receiving_address  amount transaction_type  \
# 458                 NaN               NaN     NaN              NaN
# 487                 NaN               NaN     NaN              NaN
# 835                 NaN               NaN     NaN              NaN
# 970                 NaN               NaN     NaN              NaN
# 979                 NaN               NaN     NaN              NaN
# ...                 ...               ...     ...              ...
# 1047803             NaN               NaN     NaN              NaN
# 1047825             NaN               NaN     NaN              NaN
# 1048006             NaN               NaN     NaN              NaN
# 1048137             NaN               NaN     NaN              NaN
# 1048219             NaN               NaN     NaN              NaN
#
#         location_region  ip_prefix  login_frequency  session_duration  \
# 458                 NaN        NaN              NaN               NaN
# ...

# %%
df.head()
# Out:
#                               sending_address  \
# 0  0x9d32d0bf2c00f41ce7ca01b66e174cc4dcb0c1da
# 1  0xd6e251c23cbf52dbd472f079147873e655d8096f
# 2  0x2e0925b922fed01f6a85d213ae2718f54b8ca305
# 3  0x93efefc25fcaf31d7695f28018d7a11ece55457f
# 4  0xad3b8de45d63f5cce28aef9a82cf30c397c6ceb9
#
#                             receiving_address   amount transaction_type  \
# 0  0x39f82e1c09bc6d7baccc1e79e5621ff812f50572  67435.0         transfer
# 1  0x51e8fbe24f124e0e30a614e14401b9bbfed5384c      1.0         purchase
# 2  0x52c7911879f783d590af45bda0c0ef2b8536706f  66211.0         purchase
# 3  0x8ac3b7bd531b3a833032f07d4e47c7af6ea7bace  14998.0         transfer
# 4  0x6fdc047c2391615b3facd79b4588c7e9106e49f2  66002.0             sale
#
#   location_region  ip_prefix  login_frequency  session_duration  \
# 0          Europe    192.000              3.0              48.0
# 1   South America    172.000              5.0              61.0
# ...

# %%
df.columns
# Out:
# Index(['sending_address', 'receiving_address', 'amount', 'transaction_type',
#        'location_region', 'ip_prefix', 'login_frequency', 'session_duration',
#        'purchase_pattern', 'age_group', 'risk_score', 'anomaly',
#        'transaction_datetime'],
#       dtype='str')

# %%
str_columns = [
    "sending_address",
    "receiving_address",
    "transaction_type",
    "location_region",
    "ip_prefix",
    "purchase_pattern",
    "age_group",
    "anomaly"
]

for col in str_columns:
    df[df[col].isin(["none", "null", "n/a", ""])] = None

# %%
df[df[str_columns].isna().any(axis=1)]
# Out:
#         sending_address receiving_address  amount transaction_type  \
# 458                 NaN               NaN     NaN              NaN
# 487                 NaN               NaN     NaN              NaN
# 835                 NaN               NaN     NaN              NaN
# 970                 NaN               NaN     NaN              NaN
# 979                 NaN               NaN     NaN              NaN
# ...                 ...               ...     ...              ...
# 1047803             NaN               NaN     NaN              NaN
# 1047825             NaN               NaN     NaN              NaN
# 1048006             NaN               NaN     NaN              NaN
# 1048137             NaN               NaN     NaN              NaN
# 1048219             NaN               NaN     NaN              NaN
#
#         location_region  ip_prefix  login_frequency  session_duration  \
# 458                 NaN        NaN              NaN               NaN
# ...

# %%
df["risk_score"] = pd.to_numeric(df["risk_score"], errors="coerce")

# %%
df[df["risk_score"] > 100]
# Out:
# Empty DataFrame
# Columns: [sending_address, receiving_address, amount, transaction_type, location_region, ip_prefix, login_frequency, session_duration, purchase_pattern, age_group, risk_score, anomaly, transaction_datetime]
# Index: []

# %%
df[df["risk_score"].isna()]
# Out:
#                                     sending_address  \
# 12       0xfcf9a3467d3d93688fb17b4ebb6b681b1fa29f94
# 13       0xd2cff98e8e707049db92500414fec6f0bb5c895c
# 21       0xddbe1291b454f9b8699220f1e8724aa641ef4b42
# 81       0xffa670245089044b1e355508a7843692a25a5e52
# 301      0x4976201c394fa2b954bc71953b4d2482054874e3
# ...                                             ...
# 1048137                                         NaN
# 1048219                                         NaN
# 1048288  0x60e69251a33fe222ea67c6f5769cb803ebb9c77c
# 1048340  0x48a01986b2d20dc02ae4e7fc2d97941d17ee0248
# 1048393  0xd620eeb117bf8e6ebfb7c8d0df00583a1d72fe43
#
#                                   receiving_address   amount transaction_type  \
# 12       0x6d4f7db757a1bd6bb43029ee13c037651ca20c74  65319.0         purchase
# 13       0x2e0925b922fed01f6a85d213ae2718f54b8ca305  67174.0         purchase
# 21       0x51c0d24ccc5d9b0dd793052cb2d41efde2568056  15462.0             sale
# ...

# %%
df.isna().sum()
# Out:
# sending_address          5641
# receiving_address        5641
# amount                   5641
# transaction_type         5641
# location_region          5641
# ip_prefix                5641
# login_frequency          5641
# session_duration         5641
# purchase_pattern         5641
# age_group                5641
# risk_score              11308
# anomaly                  5641
# transaction_datetime     5641
# dtype: int64

# %%
df.dropna(subset=["sending_address", "receiving_address"], inplace=True)

# %%
df.isna().sum()
# Out:
# sending_address            0
# receiving_address          0
# amount                     0
# transaction_type           0
# location_region            0
# ip_prefix                  0
# login_frequency            0
# session_duration           0
# purchase_pattern           0
# age_group                  0
# risk_score              5667
# anomaly                    0
# transaction_datetime       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df[
    df.duplicated(
        subset=[
            "sending_address",
            "receiving_address"
        ],
        keep=False
    )
]
# Out:
#                                     sending_address  \
# 0        0x9d32d0bf2c00f41ce7ca01b66e174cc4dcb0c1da
# 1        0xd6e251c23cbf52dbd472f079147873e655d8096f
# 2        0x2e0925b922fed01f6a85d213ae2718f54b8ca305
# 3        0x93efefc25fcaf31d7695f28018d7a11ece55457f
# 4        0xad3b8de45d63f5cce28aef9a82cf30c397c6ceb9
# ...                                             ...
# 1048570  0xc4f5d6d031cba61e837c43c5d5f9f27005017bfd
# 1048571  0xc028752d06eb95cdd6a708346ba0849e2495fc3d
# 1048572  0xe3a75298a17d6e04d2bd819f9ead13bbc87b110b
# 1048573  0x6a341efbef4e656e62c4164324aeb6ebfb6f1502
# 1048574  0xdb53cb7e6d171afff8201f72ec4ce4811fe507a8
#
#                                   receiving_address   amount transaction_type  \
# 0        0x39f82e1c09bc6d7baccc1e79e5621ff812f50572  67435.0         transfer
# 1        0x51e8fbe24f124e0e30a614e14401b9bbfed5384c      1.0         purchase
# 2        0x52c7911879f783d590af45bda0c0ef2b8536706f  66211.0         purchase
# ...

# %%
df[
    (df["sending_address"] == "0x9d32d0bf2c00f41ce7ca01b66e174cc4dcb0c1da") &
    (df["receiving_address"] == "0x39f82e1c09bc6d7baccc1e79e5621ff812f50572")
]
# Out:
#                                     sending_address  \
# 0        0x9d32d0bf2c00f41ce7ca01b66e174cc4dcb0c1da
# 2710     0x9d32d0bf2c00f41ce7ca01b66e174cc4dcb0c1da
# 5420     0x9d32d0bf2c00f41ce7ca01b66e174cc4dcb0c1da
# 8130     0x9d32d0bf2c00f41ce7ca01b66e174cc4dcb0c1da
# 10840    0x9d32d0bf2c00f41ce7ca01b66e174cc4dcb0c1da
# ...                                             ...
# 1035384  0x9d32d0bf2c00f41ce7ca01b66e174cc4dcb0c1da
# 1038094  0x9d32d0bf2c00f41ce7ca01b66e174cc4dcb0c1da
# 1040804  0x9d32d0bf2c00f41ce7ca01b66e174cc4dcb0c1da
# 1043514  0x9d32d0bf2c00f41ce7ca01b66e174cc4dcb0c1da
# 1046224  0x9d32d0bf2c00f41ce7ca01b66e174cc4dcb0c1da
#
#                                   receiving_address   amount transaction_type  \
# 0        0x39f82e1c09bc6d7baccc1e79e5621ff812f50572  67435.0         transfer
# 2710     0x39f82e1c09bc6d7baccc1e79e5621ff812f50572   5334.0         transfer
# 5420     0x39f82e1c09bc6d7baccc1e79e5621ff812f50572  17234.0         transfer
# ...
